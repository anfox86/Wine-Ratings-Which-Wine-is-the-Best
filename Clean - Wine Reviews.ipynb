# %%
#Load in libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Read in csv files
red = pd.read_csv('Red.csv')
white = pd.read_csv('White.csv')
sparkling = pd.read_csv('Sparkling.csv')
rose = pd.read_csv('Rose.csv')

# %%
#Starting with Rose since it looks the smallest
rose
# Out:
#                                  Name   Country             Region  \
# 0          Mad Méditerranée Rosé 2019    France       Méditerranée
# 1                    Redoma Rosé 2019  Portugal              Douro
# 2    Fantini Cerasuolo d'Abruzzo 2019     Italy            Abruzzo
# 3              Mount Hermon Rosé 2017    Israel            Galilee
# 4                  La Villa Rosé 2018    France          Languedoc
# ..                                ...       ...                ...
# 392          Côte des Roses Rosé 2019    France          Languedoc
# 393                       M Rosé 2019    France  Côtes de Provence
# 394        Whispering Angel Rosé 2019    France  Côtes de Provence
# 395             Vinho Verde Rosé N.V.  Portugal        Vinho Verde
# 396            The Original Rosé N.V.  Portugal              Douro
#
#                      Winery  Rating  NumberOfRatings  Price  Year
# 0        Château Camparnaud     4.0               25  10.11  2019
# ...

# %% [markdown]
# ```
# There are only 8 variables in this dataset and all of them I plan to use at some point, so I don't need to remove any columns like other projects. First thing I want to look at is whether there are any null values.
# ```

# %%
#look for null values
rose.isnull().sum()
# Out:
# Name               0
# Country            0
# Region             0
# Winery             0
# Rating             0
# NumberOfRatings    0
# Price              0
# Year               0
# dtype: int64

# %%
#describe rose
rose.describe()
# Out:
#            Rating  NumberOfRatings       Price
# count  397.000000       397.000000  397.000000
# mean     3.741310       261.727960   12.525743
# std      0.273042      1568.108597   16.037644
# min      2.700000        25.000000    3.670000
# 25%      3.600000        40.000000    7.190000
# 50%      3.700000        72.000000    8.900000
# 75%      3.900000       167.000000   12.850000
# max      4.800000     29531.000000  249.000000

# %%
#add a column for Type
rose.insert(0, 'Type', 'Rose')

# %%
#verify new column is present
rose
# Out:
#      Type                              Name   Country             Region  \
# 0    Rose        Mad Méditerranée Rosé 2019    France       Méditerranée
# 1    Rose                  Redoma Rosé 2019  Portugal              Douro
# 2    Rose  Fantini Cerasuolo d'Abruzzo 2019     Italy            Abruzzo
# 3    Rose            Mount Hermon Rosé 2017    Israel            Galilee
# 4    Rose                La Villa Rosé 2018    France          Languedoc
# ..    ...                               ...       ...                ...
# 392  Rose          Côte des Roses Rosé 2019    France          Languedoc
# 393  Rose                       M Rosé 2019    France  Côtes de Provence
# 394  Rose        Whispering Angel Rosé 2019    France  Côtes de Provence
# 395  Rose             Vinho Verde Rosé N.V.  Portugal        Vinho Verde
# 396  Rose            The Original Rosé N.V.  Portugal              Douro
#
#                      Winery  Rating  NumberOfRatings  Price  Year
# ...

# %%
#Look at sparkling
sparkling
# Out:
#                                              Name      Country  \
# 0                      Crémant de Loire Brut 2017       France
# 1     Vicar's Choice Sauvignon Blanc Bubbles 2019  New Zealand
# 2                     Crémant de Limoux Brut N.V.       France
# 3                               Athesis Brut 2016        Italy
# 4        Blanc de Blancs Réserve Brut Nature N.V.      Germany
# ...                                           ...          ...
# 1002         Special Cuvée Brut Aÿ Champagne N.V.       France
# 1003                  Brut Premier Champagne N.V.       France
# 1004                 Impérial Brut Champagne N.V.       France
# 1005            Brut (Carte Jaune) Champagne N.V.       France
# 1006                          Brut Champagne N.V.       France
#
#                      Region            Winery  Rating  NumberOfRatings  \
# 0          Crémant de Loire  Langlois-Chateau     3.9               25
# ...

# %%
#look for null values
sparkling.isnull().sum()
# Out:
# Name               0
# Country            0
# Region             0
# Winery             0
# Rating             0
# NumberOfRatings    0
# Price              0
# Year               0
# dtype: int64

# %%
#Look at description of dataset
sparkling.describe()
# Out:
#             Rating  NumberOfRatings        Price
# count  1007.000000      1007.000000  1007.000000
# mean      3.880834      1506.080437    34.803426
# std       0.269194      5731.196776    47.288413
# min       3.200000        25.000000     3.150000
# 25%       3.700000       102.000000    11.900000
# 50%       3.800000       259.000000    19.450000
# 75%       4.100000       844.000000    39.045000
# max       4.700000     94287.000000   495.000000

# %%
#add column type
sparkling.insert(0, 'Type', 'Sparkling')

# %%
#verify new column is present
sparkling
# Out:
#            Type                                         Name      Country  \
# 0     Sparkling                   Crémant de Loire Brut 2017       France
# 1     Sparkling  Vicar's Choice Sauvignon Blanc Bubbles 2019  New Zealand
# 2     Sparkling                  Crémant de Limoux Brut N.V.       France
# 3     Sparkling                            Athesis Brut 2016        Italy
# 4     Sparkling     Blanc de Blancs Réserve Brut Nature N.V.      Germany
# ...         ...                                          ...          ...
# 1002  Sparkling         Special Cuvée Brut Aÿ Champagne N.V.       France
# 1003  Sparkling                  Brut Premier Champagne N.V.       France
# 1004  Sparkling                 Impérial Brut Champagne N.V.       France
# 1005  Sparkling            Brut (Carte Jaune) Champagne N.V.       France
# 1006  Sparkling                          Brut Champagne N.V.       France
#
#                      Region            Winery  Rating  NumberOfRatings  \
# ...

# %%
#Look at white
white
# Out:
#                          Name      Country                      Region  \
# 0             Vermentino 2017        Italy                     Toscana
# 1           Ronco Broilo 2010        Italy  Colli Orientali del Friuli
# 2     Weisser Schiefer s 2017      Austria               Südburgenland
# 3             Chardonnay 2018      Germany                 Rheinhessen
# 4        Maganza Zibibbo 2018        Italy             Terre Siciliane
# ...                       ...          ...                         ...
# 3759     Sauvignon Blanc 2019  New Zealand                 Marlborough
# 3760   Vinho Verde Sweet N.V.     Portugal                 Vinho Verde
# 3761     Sauvignon Blanc 2018  New Zealand                 Marlborough
# 3762     Sauvignon Blanc 2019  New Zealand                 Marlborough
# 3763  Vinho Verde Branco N.V.     Portugal                 Vinho Verde
#
#                        Winery  Rating  NumberOfRatings  Price  Year
# ...

# %%
#Check for null values
white.isnull().sum()
# Out:
# Name               0
# Country            0
# Region             0
# Winery             0
# Rating             0
# NumberOfRatings    0
# Price              0
# Year               0
# dtype: int64

# %%
#description of white
white.describe()
# Out:
#             Rating  NumberOfRatings        Price
# count  3764.000000      3764.000000  3764.000000
# mean      3.817906       187.567216    20.620319
# std       0.266827      1071.470441    30.928415
# min       2.200000        25.000000     3.740000
# 25%       3.600000        43.000000     9.260000
# 50%       3.800000        77.000000    13.150000
# 75%       4.000000       174.250000    20.865000
# max       4.900000     62980.000000   681.370000

# %%
#add column for type
white.insert(0, 'Type', 'White')

# %%
#verify new column is present
white
# Out:
#        Type                     Name      Country                      Region  \
# 0     White          Vermentino 2017        Italy                     Toscana
# 1     White        Ronco Broilo 2010        Italy  Colli Orientali del Friuli
# 2     White  Weisser Schiefer s 2017      Austria               Südburgenland
# 3     White          Chardonnay 2018      Germany                 Rheinhessen
# 4     White     Maganza Zibibbo 2018        Italy             Terre Siciliane
# ...     ...                      ...          ...                         ...
# 3759  White     Sauvignon Blanc 2019  New Zealand                 Marlborough
# 3760  White   Vinho Verde Sweet N.V.     Portugal                 Vinho Verde
# 3761  White     Sauvignon Blanc 2018  New Zealand                 Marlborough
# 3762  White     Sauvignon Blanc 2019  New Zealand                 Marlborough
# 3763  White  Vinho Verde Branco N.V.     Portugal                 Vinho Verde
#
# ...

# %%
#Look at red
red
# Out:
#                                     Name        Country  \
# 0                           Pomerol 2011         France
# 1                             Lirac 2017         France
# 2     Erta e China Rosso di Toscana 2015          Italy
# 3                         Bardolino 2019          Italy
# 4         Ried Scheibner Pinot Noir 2016        Austria
# ...                                  ...            ...
# 8661                6th Sense Syrah 2016  United States
# 8662     Botrosecco Maremma Toscana 2016          Italy
# 8663                     Haut-Médoc 2010         France
# 8664                         Shiraz 2019      Australia
# 8665    Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 0                     Pomerol      Château La Providence     4.2
# 1                       Lirac         Château Mont-Redon     4.3
# 2                     Toscana                 Renzo Masi     3.9
# ...

# %%
#Look for null values in red
red.isnull().sum()
# Out:
# Name               0
# Country            0
# Region             0
# Winery             0
# Rating             0
# NumberOfRatings    0
# Price              0
# Year               0
# dtype: int64

# %%
#description of red
red.describe()
# Out:
#             Rating  NumberOfRatings        Price
# count  8666.000000      8666.000000  8666.000000
# mean      3.890342       415.287445    39.145065
# std       0.308548       899.726373    84.936307
# min       2.500000        25.000000     3.550000
# 25%       3.700000        66.000000    10.680000
# 50%       3.900000       157.000000    18.200000
# 75%       4.100000       401.000000    38.142500
# max       4.800000     20293.000000  3410.790000

# %%
#add new column of type
red.insert(0, 'Type', 'Red')

# %%
#verify column is present
red
# Out:
#      Type                                Name        Country  \
# 0     Red                        Pomerol 2011         France
# 1     Red                          Lirac 2017         France
# 2     Red  Erta e China Rosso di Toscana 2015          Italy
# 3     Red                      Bardolino 2019          Italy
# 4     Red      Ried Scheibner Pinot Noir 2016        Austria
# ...   ...                                 ...            ...
# 8661  Red                6th Sense Syrah 2016  United States
# 8662  Red     Botrosecco Maremma Toscana 2016          Italy
# 8663  Red                     Haut-Médoc 2010         France
# 8664  Red                         Shiraz 2019      Australia
# 8665  Red    Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 0                     Pomerol      Château La Providence     4.2
# 1                       Lirac         Château Mont-Redon     4.3
# ...

# %% [markdown]
# ```
# After looking at all four datasets each one of them are completely clean with no null values or major outliers that are sticking out at the moment. Also all columns are needed for my analysis so did not have to remove any columns. My next step is to combine all four datasets into one so I can load into PowerBi and start looking at things with visualizations.
# ```

# %%
#Combine dataframes into one
wine = pd.concat([rose, sparkling, white, red], axis=0)
wine
# Out:
#       Type                              Name        Country  \
# 0     Rose        Mad Méditerranée Rosé 2019         France
# 1     Rose                  Redoma Rosé 2019       Portugal
# 2     Rose  Fantini Cerasuolo d'Abruzzo 2019          Italy
# 3     Rose            Mount Hermon Rosé 2017         Israel
# 4     Rose                La Villa Rosé 2018         France
# ...    ...                               ...            ...
# 8661   Red              6th Sense Syrah 2016  United States
# 8662   Red   Botrosecco Maremma Toscana 2016          Italy
# 8663   Red                   Haut-Médoc 2010         France
# 8664   Red                       Shiraz 2019      Australia
# 8665   Red  Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 0                Méditerranée         Château Camparnaud     4.0
# 1                       Douro                   Niepoort     3.9
# ...

# %%
#Had to come back to fix this. Change N.V. in year to 0
wine['Year'].replace('N.V.', 0, inplace = True)

# %%
#save new dataframe as csv
wine.to_csv('wine_review.csv')
